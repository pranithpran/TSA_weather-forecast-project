# %%
import pandas as pd

# %%
df_test= pd.read_csv("test (1).csv")
df_test
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2016-11-01 00:00:00.000 +0100  Mostly Cloudy         NaN
# 1     2016-11-01 01:00:00.000 +0100  Mostly Cloudy         NaN
# 2     2016-11-01 02:00:00.000 +0100  Partly Cloudy         NaN
# 3     2016-11-01 03:00:00.000 +0100  Partly Cloudy         NaN
# 4     2016-11-01 04:00:00.000 +0100          Clear         NaN
# ...                             ...            ...         ...
# 2180  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 2181  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 2182  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 2183  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 2184  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            6.205556                  4.527778      0.92             8.1466
# ...

# %%
df_train = pd.read_csv("train (1).csv")
df_train
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 94263  2016-05-09 19:00:00.000 +0200  Partly Cloudy        rain
# 94264  2016-05-09 20:00:00.000 +0200  Partly Cloudy        rain
# 94265  2016-05-09 21:00:00.000 +0200  Partly Cloudy        rain
# 94266  2016-05-09 22:00:00.000 +0200  Partly Cloudy        rain
# 94267  2016-05-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df_test.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 374
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Cloud Cover                   0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 143
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Cloud Cover                   0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df_test.nunique()
# Out:
# Formatted Date              2185
# Summary                       10
# Precip Type                    1
# Temperature (C)             1583
# Apparent Temperature (C)    1651
# Humidity                      77
# Wind Speed (km/h)            874
# Wind Bearing (degrees)       331
# Visibility (km)              522
# Cloud Cover                    1
# Pressure (millibars)        1076
# Daily Summary                 32
# dtype: int64

# %%
df_train.nunique()
# Out:
# Formatted Date              94244
# Summary                        26
# Precip Type                     2
# Temperature (C)              7564
# Apparent Temperature (C)     8981
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               935
# Cloud Cover                     1
# Pressure (millibars)         4979
# Daily Summary                 207
# dtype: int64

# %%
df_train[["Formatted Date","Temperature (C)"]]
# Out:
#                       Formatted Date  Temperature (C)
# 0      2006-04-01 00:00:00.000 +0200         9.472222
# 1      2006-04-01 01:00:00.000 +0200         9.355556
# 2      2006-04-01 02:00:00.000 +0200         9.377778
# 3      2006-04-01 03:00:00.000 +0200         8.288889
# 4      2006-04-01 04:00:00.000 +0200         8.755556
# ...                              ...              ...
# 94263  2016-05-09 19:00:00.000 +0200        19.972222
# 94264  2016-05-09 20:00:00.000 +0200        17.816667
# 94265  2016-05-09 21:00:00.000 +0200        13.938889
# 94266  2016-05-09 22:00:00.000 +0200        12.733333
# 94267  2016-05-09 23:00:00.000 +0200        13.038889
#
# [94268 rows x 2 columns]

# %%
df_train["Formatted_Date"]=pd.to_datetime(df_train["Formatted Date"],utc=True)

# %%
df_train
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 94263  2016-05-09 19:00:00.000 +0200  Partly Cloudy        rain
# 94264  2016-05-09 20:00:00.000 +0200  Partly Cloudy        rain
# 94265  2016-05-09 21:00:00.000 +0200  Partly Cloudy        rain
# 94266  2016-05-09 22:00:00.000 +0200  Partly Cloudy        rain
# 94267  2016-05-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df_train
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 94263  2016-05-09 19:00:00.000 +0200  Partly Cloudy        rain
# 94264  2016-05-09 20:00:00.000 +0200  Partly Cloudy        rain
# 94265  2016-05-09 21:00:00.000 +0200  Partly Cloudy        rain
# 94266  2016-05-09 22:00:00.000 +0200  Partly Cloudy        rain
# 94267  2016-05-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df_train[["Formatted Date","Temperature (C)"]].sort_values(by="Formatted Date")
# Out:
#                       Formatted Date  Temperature (C)
# 2880   2006-01-01 00:00:00.000 +0100         0.577778
# 2881   2006-01-01 01:00:00.000 +0100         1.161111
# 2882   2006-01-01 02:00:00.000 +0100         1.666667
# 2883   2006-01-01 03:00:00.000 +0100         1.711111
# 2884   2006-01-01 04:00:00.000 +0100         1.183333
# ...                              ...              ...
# 89728  2016-12-31 19:00:00.000 +0100         0.488889
# 89729  2016-12-31 20:00:00.000 +0100         0.072222
# 89730  2016-12-31 21:00:00.000 +0100        -0.233333
# 89731  2016-12-31 22:00:00.000 +0100        -0.472222
# 89732  2016-12-31 23:00:00.000 +0100        -0.677778
#
# [94268 rows x 2 columns]

# %%
df3 = pd.concat([df_train,df_test],axis=0,ignore_index=True)
df3
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df_train['Formatted_Date']=pd.to_datetime(df_train['Formatted Date'],utc=True)

# %%
df_train.dtypes
# Out:
# Formatted Date                           object
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                    int64
# Visibility (km)                         float64
# Cloud Cover                               int64
# Pressure (millibars)                    float64
# Daily Summary                            object
# Formatted_Date              datetime64[ns, UTC]
# dtype: object

# %%
df_train.dropna(inplace=True)

# %%
df_train.drop('Formatted_Date',axis=1,inplace=True)

# %%
df_train['Formatted Date']=pd.to_datetime(df_train['Formatted Date'],utc=True)

# %%
df_train.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                    int64
# Visibility (km)                         float64
# Cloud Cover                               int64
# Pressure (millibars)                    float64
# Daily Summary                            object
# dtype: object

# %%
df_train.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Cloud Cover                 0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
df_train.drop_duplicates(inplace=True)

# %%
df3.drop('Formatted_Date',axis=1,inplace=True)

# %%
df3.drop_duplicates(inplace=True)

# %%
df3.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)        int64
# Visibility (km)             float64
# Cloud Cover                   int64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df3.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Cloud Cover                   0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df3['Temperature (C)'].corr(df3['Apparent Temperature (C)'])
# Out:
# 0.9926254234649435

# %%
df3['Formatted Date']=pd.to_datetime(df3['Formatted Date'],utc=True)

# %%
import datetime as dt

# %%
df3['Date'] = df3['Formatted Date'].dt.date

# %%
df3
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
t = df3['Date'].value_counts()

# %%
t=t[t!=24]

# %%
df3 = df3[~(df3['Date']==t.index[-1])]

# %%
df3[df3['Date']==t.index[0]].sort_values('Formatted Date')
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 89710 2016-12-31 00:00:00+00:00  Mostly Cloudy        snow        -1.161111
# 89711 2016-12-31 01:00:00+00:00  Mostly Cloudy        snow        -1.488889
# 89712 2016-12-31 02:00:00+00:00  Mostly Cloudy        snow        -1.822222
# 89713 2016-12-31 03:00:00+00:00  Mostly Cloudy        snow        -2.077778
# 89714 2016-12-31 04:00:00+00:00  Mostly Cloudy        snow        -2.177778
# 89715 2016-12-31 05:00:00+00:00  Mostly Cloudy        snow        -2.050000
# 89716 2016-12-31 06:00:00+00:00  Mostly Cloudy        snow        -1.655556
# 89717 2016-12-31 07:00:00+00:00  Mostly Cloudy        snow        -1.016667
# 89718 2016-12-31 08:00:00+00:00  Mostly Cloudy        snow        -0.194444
# 89719 2016-12-31 09:00:00+00:00  Mostly Cloudy        rain         0.705556
# 89720 2016-12-31 10:00:00+00:00  Mostly Cloudy        rain         1.550000
# ...

# %%
df3[df3['Date']==t.index[1]].sort_values('Formatted Date')
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 73896 2014-07-14 01:00:00+00:00  Mostly Cloudy        rain        17.177778
# 73897 2014-07-14 02:00:00+00:00  Mostly Cloudy        rain        16.644444
# 73898 2014-07-14 03:00:00+00:00  Mostly Cloudy        rain        15.894444
# 73899 2014-07-14 04:00:00+00:00  Partly Cloudy        rain        16.094444
# 73900 2014-07-14 05:00:00+00:00  Partly Cloudy        rain        17.738889
# 73901 2014-07-14 06:00:00+00:00  Partly Cloudy        rain        21.655556
# 73902 2014-07-14 07:00:00+00:00  Partly Cloudy        rain        22.666667
# 73903 2014-07-14 08:00:00+00:00  Partly Cloudy        rain        24.844444
# 73904 2014-07-14 09:00:00+00:00  Partly Cloudy        rain        24.844444
# 73905 2014-07-14 10:00:00+00:00  Partly Cloudy        rain        26.066667
# 73906 2014-07-14 11:00:00+00:00  Partly Cloudy        rain        27.177778
# ...

# %%
df3[df3['Date']==t.index[2]].sort_values('Formatted Date')
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 73874 2014-07-13 00:00:00+00:00  Partly Cloudy        rain        15.966667
# 73875 2014-07-13 01:00:00+00:00  Partly Cloudy        rain        16.044444
# 73876 2014-07-13 02:00:00+00:00  Partly Cloudy        rain        15.561111
# 73877 2014-07-13 03:00:00+00:00  Mostly Cloudy        rain        16.144444
# 73878 2014-07-13 04:00:00+00:00  Partly Cloudy        rain        16.072222
# 73879 2014-07-13 05:00:00+00:00  Partly Cloudy        rain        17.788889
# 73880 2014-07-13 06:00:00+00:00  Partly Cloudy        rain        21.111111
# 73881 2014-07-13 07:00:00+00:00  Partly Cloudy        rain        23.816667
# 73882 2014-07-13 08:00:00+00:00  Partly Cloudy        rain        26.016667
# 73883 2014-07-13 09:00:00+00:00  Partly Cloudy        rain        25.000000
# 73884 2014-07-13 10:00:00+00:00  Partly Cloudy        rain        24.683333
# ...

# %%
error = t.index
error
# Out:
# Index([2016-12-31, 2014-07-14, 2014-07-13, 2005-12-31], dtype='object', name='Date')

# %%
df3.drop("Cloud Cover",axis=1,inplace=True)
# Out:
# /var/folders/zl/763j_sh575dclj25sgxlp9vr0000gn/T/ipykernel_2331/219114345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop("Cloud Cover",axis=1,inplace=True)

# %%
import pandas as pd
import numpy as np
from datetime import timedelta

def data_generator(xt, new_df, k):
    # Check necessary columns
    if "Formatted Date" not in new_df.columns:
        raise KeyError("'Formatted Date' column is missing in new_df.")
    if "Date" not in new_df.columns:
        raise KeyError("'Date' column is missing in new_df.")
    
    # Ensure 'Formatted Date' is datetime
    new_df["Formatted Date"] = pd.to_datetime(new_df["Formatted Date"], errors="coerce")
    
    # Ensure 'Hour' column exists
    if "Hour" not in new_df.columns:
        new_df["Hour"] = new_df["Formatted Date"].dt.hour
    
    # Filter rows for the given date
    g = new_df[new_df["Date"] == xt].copy()
    if g.empty:
        raise ValueError(f"No data found for the specified date: {xt}")
    
    if "Hour" not in g.columns:
        g["Hour"] = g["Formatted Date"].dt.hour
    
    # Generate missing hours
    q = pd.Series(range(0, 24))
    p = q[~(q.isin(g["Hour"].unique()))]
    md = {}
    pw = []

    for i in range(len(p)):
        gd = {}
        for j in g.columns[1:len(g.columns) - 2]:
            d_5 = [xt - timedelta(days=n) for n in range(1, k)]
            gen = new_df[(new_df["Date"].isin(d_5)) & (new_df["Hour"] == p.iloc[i])]

            if not gen.empty:
                if pd.api.types.is_object_dtype(g[j]):
                    gd[j] = gen[j].mode()[0] if not gen[j].mode().empty else None
                else:
                    gd[j] = gen[j].median()
            else:
                gd[j] = None

        md[str(xt) + " " + str(p.iloc[i])] = gd
        pw.append(p.iloc[i])

    fr = pd.DataFrame(md).T.reset_index(drop=True)
    col = fr.columns
    d1 = np.array(fr)
    mr = pd.DataFrame(d1, columns=col)
    mr["Hour"] = pw
    mr["Date"] = xt
    return mr

# %%
from datetime import timedelta

# %%
data = {
    "Date": pd.date_range("2024-01-01", periods=5).tolist() * 5,
    "Formatted Date": pd.date_range("2024-01-01", periods=25, freq="H"),
    "Value": np.random.randint(0, 100, size=25),
}
new_df = pd.DataFrame(data)

# Call the function
xt = pd.Timestamp("2024-01-02")
k = 3
result = data_generator(xt, new_df, k)
print(result)
# Out:
#         Formatted Date  Hour       Date
# 0  2024-01-01 00:00:00     0 2024-01-02
# 1                  NaT     2 2024-01-02
# 2                  NaT     3 2024-01-02
# 3                  NaT     4 2024-01-02
# 4  2024-01-01 05:00:00     5 2024-01-02
# 5                  NaT     7 2024-01-02
# 6                  NaT     8 2024-01-02
# 7                  NaT     9 2024-01-02
# 8  2024-01-01 10:00:00    10 2024-01-02
# 9                  NaT    12 2024-01-02
# 10                 NaT    13 2024-01-02
# 11                 NaT    14 2024-01-02
# 12 2024-01-01 15:00:00    15 2024-01-02
# 13                 NaT    17 2024-01-02
# 14                 NaT    18 2024-01-02
# 15                 NaT    19 2024-01-02
# 16 2024-01-01 20:00:00    20 2024-01-02
# 17                 NaT    22 2024-01-02
# 18                 NaT    23 2024-01-02
# ...

# %%
l = data_generator(error[-2],df3,6)
l
# Out:
# /var/folders/zl/763j_sh575dclj25sgxlp9vr0000gn/T/ipykernel_2331/4276407505.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Formatted Date"] = pd.to_datetime(new_df["Formatted Date"], errors="coerce")
# /var/folders/zl/763j_sh575dclj25sgxlp9vr0000gn/T/ipykernel_2331/4276407505.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Hour"] = new_df["Formatted Date"].dt.hour
#          Summary Precip Type Temperature (C) Apparent Temperature (C)  \
# ...

# %%
o = data_generator(error[-2],df3,6)
o
# Out:
# /var/folders/zl/763j_sh575dclj25sgxlp9vr0000gn/T/ipykernel_2331/4276407505.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Formatted Date"] = pd.to_datetime(new_df["Formatted Date"], errors="coerce")
#          Summary Precip Type Temperature (C) Apparent Temperature (C)  \
# 0  Mostly Cloudy        rain       16.838889                16.838889
# 1  Mostly Cloudy        rain            15.7                     15.7
#
#   Humidity Wind Speed (km/h) Wind Bearing (degrees) Visibility (km)  \
# 0      0.9           11.0607                  260.0         15.8263
# 1     0.89            6.3756                  225.0         14.6832
#
#   Pressure (millibars)                      Daily Summary  Hour        Date
# ...

# %%
p = data_generator(error[-3],df3,6)
p
# Out:
# /var/folders/zl/763j_sh575dclj25sgxlp9vr0000gn/T/ipykernel_2331/4276407505.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Formatted Date"] = pd.to_datetime(new_df["Formatted Date"], errors="coerce")
#          Summary Precip Type Temperature (C) Apparent Temperature (C)  \
# 0  Mostly Cloudy        rain       15.966667                15.966667
#
#   Humidity Wind Speed (km/h) Wind Bearing (degrees) Visibility (km)  \
# 0     0.93            5.8121                  241.0          11.914
#
#   Pressure (millibars)                      Daily Summary  Hour        Date
# 0              1006.19  Mostly cloudy throughout the day.     0  2014-07-14

# %%
df3['Hour'] = df3['Formatted Date'].dt.hour
# Out:
# /var/folders/zl/763j_sh575dclj25sgxlp9vr0000gn/T/ipykernel_2331/3007175585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Hour'] = df3['Formatted Date'].dt.hour
